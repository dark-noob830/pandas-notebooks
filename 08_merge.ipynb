# %%
import pandas as pd
import numpy as np

# %%
g1 = pd.read_csv('data/groups1.csv')
g1
# Out:
#       group_id                                              name  category_id  \
# 0         6388                            Alternative Health NYC           14
# 1         6510                         Alternative Energy Meetup            4
# 2         8458                                 NYC Animal Rights           26
# 3         8940                     The New York City Anime Group           29
# 4        10104                                NYC Pit Bull Group           26
# ...        ...                                               ...          ...
# 7994  18875285  NYC's Physically Fit, Active, & Athletic Singles           30
# 7995  18876571                   Shambhala Meditation Center NYC           14
# 7996  18876811                                   Chicago Gophers           34
# 7997  18877490                NYC Students & Young Entrepreneurs            2
# 7998  18878056                  NYC Green Bay Packer Fans Meetup           32
#
#       city_id
# 0       10001
# ...

# %%
g2 = pd.read_csv('data/groups2.csv')
g2
# Out:
#       group_id                                               name  \
# 0     18879327                                       BachataMania
# 1     18880221  Photoshoot Chicago - Photography and Modeling ...
# 2     18880426  Chicago Adult Push / Kick Scooter Group Riding...
# 3     18880495                  Chicago International Soccer Club
# 4     18880695                   Impact.tech San Francisco Meetup
# ...        ...                                                ...
# 8326  26377464                                            Shinect
# 8327  26377698  The art of getting what you want [conference s...
# 8328  26378067                        Streeterville Running Group
# 8329  26378128                                     Just Dance NYC
# 8330  26378470           FREE Arabic Chicago Evanston North Burbs
#
#       category_id  city_id
# 0               5    10001
# 1              27    60601
# 2              31    60601
# 3              32    60601
# 4               2    94101
# ...

# %%
cat = pd.read_csv('data/categories.csv')
cat
# Out:
#     category_id               category_name
# 0             1              Arts & Culture
# 1             3          Cars & Motorcycles
# 2             4     Community & Environment
# 3             5                     Dancing
# 4             6        Education & Learning
# 5             9                     Fitness
# 6            10                Food & Drink
# 7            11                       Games
# 8            14          Health & Wellbeing
# 9            15            Hobbies & Crafts
# 10           16  Language & Ethnic Identity
# 11           17                   Lifestyle
# 12           18                  Book Clubs
# 13           20               Movies & Film
# 14           21                       Music
# 15           22      New Age & Spirituality
# 16           23        Outdoors & Adventure
# 17           24                  Paranormal
# 18           25            Parents & Family
# 19           27                 Photography
# ...

# %%
city = pd.read_csv('data/cities.csv',)
city
# Out:
#        id                 city state    zip
# 0    7093        West New York    NJ   7093
# 1   10001             New York    NY  10001
# 2   13417       New York Mills    NY  13417
# 3   46312         East Chicago    IN  46312
# 4   56567       New York Mills    MN  56567
# 5   60064        North Chicago    IL  60064
# 6   60185         West Chicago    IL  60185
# 7   60411      Chicago Heights    IL  60411
# 8   60415        Chicago Ridge    IL  60415
# 9   60601              Chicago    IL  60290
# 10  94080  South San Francisco    CA  94080
# 11  94101        San Francisco    CA  94101
# 12  95712         Chicago Park    CA  95712

# %%
city = pd.read_csv('data/cities.csv',dtype={'zip':'str'})
city
# Out:
#        id                 city state    zip
# 0    7093        West New York    NJ  07093
# 1   10001             New York    NY  10001
# 2   13417       New York Mills    NY  13417
# 3   46312         East Chicago    IN  46312
# 4   56567       New York Mills    MN  56567
# 5   60064        North Chicago    IL  60064
# 6   60185         West Chicago    IL  60185
# 7   60411      Chicago Heights    IL  60411
# 8   60415        Chicago Ridge    IL  60415
# 9   60601              Chicago    IL  60290
# 10  94080  South San Francisco    CA  94080
# 11  94101        San Francisco    CA  94101
# 12  95712         Chicago Park    CA  95712

# %%
pd.concat([g1,g2])
# Out:
#       group_id                                               name  \
# 0         6388                             Alternative Health NYC
# 1         6510                          Alternative Energy Meetup
# 2         8458                                  NYC Animal Rights
# 3         8940                      The New York City Anime Group
# 4        10104                                 NYC Pit Bull Group
# ...        ...                                                ...
# 8326  26377464                                            Shinect
# 8327  26377698  The art of getting what you want [conference s...
# 8328  26378067                        Streeterville Running Group
# 8329  26378128                                     Just Dance NYC
# 8330  26378470           FREE Arabic Chicago Evanston North Burbs
#
#       category_id  city_id
# 0              14    10001
# 1               4    10001
# 2              26    10001
# 3              29    10001
# 4              26    10001
# ...

# %%
pd.concat([g1,g2],ignore_index=True)
# Out:
#        group_id                                               name  \
# 0          6388                             Alternative Health NYC
# 1          6510                          Alternative Energy Meetup
# 2          8458                                  NYC Animal Rights
# 3          8940                      The New York City Anime Group
# 4         10104                                 NYC Pit Bull Group
# ...         ...                                                ...
# 16325  26377464                                            Shinect
# 16326  26377698  The art of getting what you want [conference s...
# 16327  26378067                        Streeterville Running Group
# 16328  26378128                                     Just Dance NYC
# 16329  26378470           FREE Arabic Chicago Evanston North Burbs
#
#        category_id  city_id
# 0               14    10001
# 1                4    10001
# 2               26    10001
# 3               29    10001
# ...

# %%
groups = pd.concat([g1,g2],keys=['G1','G2'])
groups
# Out:
#          group_id                                               name  \
# G1 0         6388                             Alternative Health NYC
#    1         6510                          Alternative Energy Meetup
#    2         8458                                  NYC Animal Rights
#    3         8940                      The New York City Anime Group
#    4        10104                                 NYC Pit Bull Group
# ...           ...                                                ...
# G2 8326  26377464                                            Shinect
#    8327  26377698  The art of getting what you want [conference s...
#    8328  26378067                        Streeterville Running Group
#    8329  26378128                                     Just Dance NYC
#    8330  26378470           FREE Arabic Chicago Evanston North Burbs
#
#          category_id  city_id
# G1 0              14    10001
#    1               4    10001
#    2              26    10001
# ...

# %%
groups.loc['G1',0]
# Out:
# group_id                         6388
# name           Alternative Health NYC
# category_id                        14
# city_id                         10001
# Name: (G1, 0), dtype: object

# %%
groups = pd.concat([g1,g2],ignore_index=True)
groups
# Out:
#        group_id                                               name  \
# 0          6388                             Alternative Health NYC
# 1          6510                          Alternative Energy Meetup
# 2          8458                                  NYC Animal Rights
# 3          8940                      The New York City Anime Group
# 4         10104                                 NYC Pit Bull Group
# ...         ...                                                ...
# 16325  26377464                                            Shinect
# 16326  26377698  The art of getting what you want [conference s...
# 16327  26378067                        Streeterville Running Group
# 16328  26378128                                     Just Dance NYC
# 16329  26378470           FREE Arabic Chicago Evanston North Burbs
#
#        category_id  city_id
# 0               14    10001
# 1                4    10001
# 2               26    10001
# 3               29    10001
# ...

# %%
groups.merge(right=cat,how='left',on='category_id')
# Out:
#        group_id                                               name  \
# 0          6388                             Alternative Health NYC
# 1          6510                          Alternative Energy Meetup
# 2          8458                                  NYC Animal Rights
# 3          8940                      The New York City Anime Group
# 4         10104                                 NYC Pit Bull Group
# ...         ...                                                ...
# 16325  26377464                                            Shinect
# 16326  26377698  The art of getting what you want [conference s...
# 16327  26378067                        Streeterville Running Group
# 16328  26378128                                     Just Dance NYC
# 16329  26378470           FREE Arabic Chicago Evanston North Burbs
#
#        category_id  city_id            category_name
# 0               14    10001       Health & Wellbeing
# 1                4    10001  Community & Environment
# ...

# %%
groups.merge(right=cat,how='inner',on='category_id')
# Out:
#       group_id                                               name  \
# 0         6388                             Alternative Health NYC
# 1         6510                          Alternative Energy Meetup
# 2         8940                      The New York City Anime Group
# 3        10359   NYC International Arabic Language & Culture Club
# 4        12111  The New York City American Sign Language Meetu...
# ...        ...                                                ...
# 8032  26374579              Digital Film Academy Production Pitch
# 8033  26374655                                 Vocabulary workhop
# 8034  26377698  The art of getting what you want [conference s...
# 8035  26378067                        Streeterville Running Group
# 8036  26378128                                     Just Dance NYC
#
#       category_id  city_id               category_name
# 0              14    10001          Health & Wellbeing
# 1               4    10001     Community & Environment
# ...

# %%
groups.merge(right=cat,how='right',on='category_id')
# Out:
#         group_id                                         name  category_id  \
# 0       153288.0           Chicago Theater Goers Meetup Group            1
# 1       178198.0                   Union Square Reading Group            1
# 2       234020.0       The San Francisco Figure Drawing Group            1
# 3       292067.0  The San Francisco Play Reading Meetup Group            1
# 4       297702.0                         NEW YORK MUSEUM CLUB            1
# ...          ...                                          ...          ...
# 8033  26231454.0                      We Love Diverse Stories           36
# 8034  26246909.0             Writing to Heal, Writing to Grow           36
# 8035  26265769.0    Query Critique Group For Aspiring Authors           36
# 8036  26318734.0              San Francisco UX Writers Meetup           36
# 8037         NaN                                          NaN           37
#
#       city_id   category_name
# 0     60601.0  Arts & Culture
# ...

# %%
groups.merge(right=cat,how='outer',on='category_id')
# Out:
#          group_id                                         name  category_id  \
# 0        153288.0           Chicago Theater Goers Meetup Group            1
# 1        178198.0                   Union Square Reading Group            1
# 2        234020.0       The San Francisco Figure Drawing Group            1
# 3        292067.0  The San Francisco Play Reading Meetup Group            1
# 4        297702.0                         NEW YORK MUSEUM CLUB            1
# ...           ...                                          ...          ...
# 16326  26231454.0                      We Love Diverse Stories           36
# 16327  26246909.0             Writing to Heal, Writing to Grow           36
# 16328  26265769.0    Query Critique Group For Aspiring Authors           36
# 16329  26318734.0              San Francisco UX Writers Meetup           36
# 16330         NaN                                          NaN           37
#
#        city_id   category_name
# ...

# %%
groups.merge(right=city,how='outer',left_on='city_id',right_on='id')
# Out:
#          group_id                                               name  \
# 0      19525264.0         West NY | Hoboken | Social Group 20s & 30s
# 1      20240670.0                                        Nerdy NJ/NY
# 2      20395344.0          The Founding Moms' Exchange: North Jersey
# 3      21130076.0            West New York Playdates for little ones
# 4      21825714.0                              Women~Wellness~Wisdom
# ...           ...                                                ...
# 16329  26373602.0  Earndotcom: SF's most awesome digital currency...
# 16330  26374655.0                                 Vocabulary workhop
# 16331  26377464.0                                            Shinect
# 16332  26377698.0  The art of getting what you want [conference s...
# 16333         NaN                                                NaN
#
#        category_id  city_id     id           city state    zip
# 0             31.0   7093.0   7093  West New York    NJ  07093
# ...

# %%
groups.merge(right=city,how='outer',left_on='city_id',right_on='id',indicator=True)
# Out:
#          group_id                                               name  \
# 0      19525264.0         West NY | Hoboken | Social Group 20s & 30s
# 1      20240670.0                                        Nerdy NJ/NY
# 2      20395344.0          The Founding Moms' Exchange: North Jersey
# 3      21130076.0            West New York Playdates for little ones
# 4      21825714.0                              Women~Wellness~Wisdom
# ...           ...                                                ...
# 16329  26373602.0  Earndotcom: SF's most awesome digital currency...
# 16330  26374655.0                                 Vocabulary workhop
# 16331  26377464.0                                            Shinect
# 16332  26377698.0  The art of getting what you want [conference s...
# 16333         NaN                                                NaN
#
#        category_id  city_id     id           city state    zip      _merge
# ...
