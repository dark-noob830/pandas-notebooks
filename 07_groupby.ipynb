# %%
import pandas as pd
import numpy as np

# %%
ft = pd.read_csv('data/fortune1000.csv')
ft
# Out:
#                              Company  Revenues  Profits  Employees  \
# 0                            Walmart  500343.0   9862.0    2300000
# 1                        Exxon Mobil  244363.0  19710.0      71200
# 2                 Berkshire Hathaway  242137.0  44940.0     377000
# 3                              Apple  229234.0  48351.0     123000
# 4                 UnitedHealth Group  201159.0  10558.0     260000
# ..                               ...       ...      ...        ...
# 995         SiteOne Landscape Supply    1862.0     54.6       3664
# 996  Charles River Laboratories Intl    1858.0    123.4      11800
# 997                        CoreLogic    1851.0    152.2       5900
# 998                     Ensign Group    1849.0     40.5      21301
# 999                              HCP    1848.0    414.2        190
#
#                 Sector                                  Industry
# 0            Retailing                     General Merchandisers
# ...

# %%
ft[ft['Sector'] == 'Technology']
# Out:
#                     Company  Revenues  Profits  Employees      Sector  \
# 3                     Apple  229234.0  48351.0     123000  Technology
# 21                 Alphabet  110855.0  12662.0      80110  Technology
# 29                Microsoft   89950.0  21204.0     124000  Technology
# 33                      IBM   79139.0   5753.0     397800  Technology
# 34        Dell Technologies   78660.0  -3728.0     145000  Technology
# ..                      ...       ...      ...        ...         ...
# 969  Cadence Design Systems    1943.0    204.1       7214  Technology
# 970   Nuance Communications    1939.0   -151.0      11600  Technology
# 973              ServiceNow    1933.0   -149.1       6222  Technology
# 983         MKS Instruments    1916.0    339.1       4923  Technology
# 991        VeriFone Systems    1871.0   -173.8       5600  Technology
#
#                                            Industry
# 3                       Computers, Office Equipment
# ...

# %%
ft[ft['Sector'] == 'Technology'].mean(numeric_only=True)
# Out:
# Revenues     13347.789320
# Profits       1743.959804
# Employees    31036.961165
# dtype: float64

# %%
sectors = ft.groupby('Sector')
sectors

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense               25
# Apparel                           14
# Business Services                 53
# Chemicals                         33
# Energy                           107
# Engineering & Construction        27
# Financials                       155
# Food &  Drug Stores               12
# Food, Beverages & Tobacco         37
# Health Care                       71
# Hotels, Restaurants & Leisure     26
# Household Products                28
# Industrials                       49
# Materials                         45
# Media                             25
# Motor Vehicles & Parts            19
# Retailing                         77
# Technology                       103
# Telecommunications                10
# Transportation                    40
# Wholesalers                       44
# dtype: int64

# %%
len(sectors)
# Out:
# 21

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': [26, 50, 58, 98, 117, 118, 207, 224, 275, 380, 404, 406, 414, 540, 660, 661, 806, 829, 884, 930, 954, 955, 959, 975, 988], 'Apparel': [88, 241, 331, 420, 432, 526, 529, 554, 587, 678, 766, 774, 835, 861], 'Business Services': [142, 160, 187, 199, 201, 221, 235, 242, 253, 295, 325, 358, 364, 423, 462, 465, 486, 493, 497, 499, 502, 510, 528, 567, 577, 584, 591, 599, 604, 618, 649, 686, 691, 692, 700, 702, 712, 720, 738, 744, 771, 802, 810, 825, 879, 888, 894, 895, 898, 905, 922, 972, 997], 'Chemicals': [46, 189, 190, 198, 214, 263, 281, 309, 344, 351, 381, 447, 450, 454, 527, 593, 623, 648, 671, 672, 679, 704, 722, 740, 790, 836, 865, 872, 908, 932, 958, 963, 978], 'Energy': [1, 12, 27, 30, 40, 63, 89, 90, 91, 94, 104, 114, 124, 125, 134, 145, 166, 167, 175, 184, 205, 212, 213, 217, 218, 219, 222, 231, 232, 243, 248, 254, 256, 265, 268, 269, 270, 273, 307, 313, 326, 333, 335, 343, 352, 363, 371, 379, 383, 384, 387, 428, 437, 452, 456, 488, 490, 496, 498, 500, 51
# ...

# %%
sectors.first()
# Out:
#                                               Company  Revenues  Profits  \
# Sector
# Aerospace & Defense                            Boeing   93392.0   8197.0
# Apparel                                          Nike   34350.0   4240.0
# Business Services                       ManpowerGroup   21034.0    545.4
# Chemicals                                   DowDuPont   62683.0   1460.0
# Energy                                    Exxon Mobil  244363.0  19710.0
# Engineering & Construction                      Fluor   19521.0    191.4
# Financials                         Berkshire Hathaway  242137.0  44940.0
# Food &  Drug Stores                            Kroger  122662.0   1907.0
# Food, Beverages & Tobacco                     PepsiCo   63525.0   4857.0
# Health Care                        UnitedHealth Group  201159.0  10558.0
# Hotels, Restaurants & Leisure  Marriott International   22894.0   1372.0
# Household Products                   Procter & Gamble   66217.0  15326.0
# ...

# %%
sectors.last()
# Out:
#                                                    Company  Revenues  Profits  \
# Sector
# Aerospace & Defense            Aerojet Rocketdyne Holdings    1877.0     -9.2
# Apparel                               Wolverine World Wide    2350.0      0.3
# Business Services                                CoreLogic    1851.0    152.2
# Chemicals                                           Stepan    1925.0     91.6
# Energy                            Superior Energy Services    1874.0   -205.9
# Engineering & Construction                        TopBuild    1906.0    158.1
# Financials                                             HCP    1848.0    414.2
# Food &  Drug Stores                                  Freds    2064.0   -140.3
# Food, Beverages & Tobacco                        Universal    2071.0    106.3
# Health Care                                   Ensign Group    1849.0     40.5
# Hotels, Restaurants & Leisure                 Vail Resorts    1907.0    210.6
# ...

# %%
sectors.nth(3)
# Out:
#                     Company  Revenues  Profits  Employees  \
# 22               Home Depot  100904.0   8630.0     413000
# 23    Bank of America Corp.  100264.0  18232.0     209376
# 28                   Anthem   90040.0   3842.8      56000
# 30            Valero Energy   88407.0   4065.0      10015
# 33                      IBM   79139.0   5753.0     397800
# 53                    Sysco   55371.0   1142.5      66500
# 73   Charter Communications   41581.0   9895.0      94800
# 74          Delta Air Lines   41244.0   3577.0      86564
# 86                Coca-Cola   35410.0   1248.0      61800
# 87     Publix Super Markets   34837.0   2291.9     193000
# 96                       3M   31657.0   4858.0      91536
# 98         General Dynamics   30973.0   2912.0      98600
# 186  Goodyear Tire & Rubber   15377.0    346.0      64000
# 195           Newell Brands   14742.0   2748.8      49000
# 196                     CBS   14710.0    357.0      14715
# ...

# %%
sectors.head(2)
# Out:
#                       Company  Revenues  Profits  Employees  \
# 0                     Walmart  500343.0   9862.0    2300000
# 1                 Exxon Mobil  244363.0  19710.0      71200
# 2          Berkshire Hathaway  242137.0  44940.0     377000
# 3                       Apple  229234.0  48351.0     123000
# 4          UnitedHealth Group  201159.0  10558.0     260000
# 5                    McKesson  198533.0   5070.0      64500
# 6                  CVS Health  184765.0   6622.0     203000
# 7                  Amazon.com  177866.0   3033.0     566000
# 8                        AT&T  160546.0  29450.0     254000
# 9              General Motors  157311.0  -3864.0     180000
# 10                 Ford Motor  156776.0   7602.0     202000
# 11          AmerisourceBergen  153144.0    364.5      19500
# 12                    Chevron  134533.0   9195.0      51900
# 15                    Verizon  126034.0  30101.0     155400
# 16                     Kroger  122662.0   1907.0     449000
# ...

# %%
sectors.tail(2)
# Out:
#                              Company  Revenues  Profits  Employees  \
# 520         Telephone & Data Systems    5044.0    153.0       9900
# 835              Columbia Sportswear    2466.0    105.1       6188
# 839                     GNC Holdings    2453.0   -148.9      11500
# 861             Wolverine World Wide    2350.0      0.3       3700
# 900                    Snyders-Lance    2227.0    148.5       5900
# 907              Zayo Group Holdings    2200.0     85.7       3794
# 920                   LCI Industries    2148.0    132.9       9852
# 937                        Universal    2071.0    106.3      24000
# 940              Tower International    2066.0     47.6       7600
# 941                            Freds    2064.0   -140.3       7324
# 942    Foundation Building Materials    2061.0     82.5       3782
# 946             Central Garden & Pet    2055.0     78.8       4050
# 947                           Matson    2047.0    232.0       1947
# ...

# %%
sectors.get_group('Apparel')
# Out:
#                   Company  Revenues  Profits  Employees   Sector Industry
# 88                   Nike   34350.0   4240.0      74400  Apparel  Apparel
# 241                    VF   12400.0    614.9      69000  Apparel  Apparel
# 331                   PVH    8915.0    537.8      28050  Apparel  Apparel
# 420          Ralph Lauren    6653.0    -99.3      18250  Apparel  Apparel
# 432           Hanesbrands    6478.0     61.9      67200  Apparel  Apparel
# 526          Under Armour    4977.0    -48.3      11350  Apparel  Apparel
# 529          Levi Strauss    4904.0    281.4      13800  Apparel  Apparel
# 554              Tapestry    4488.3    591.0      12450  Apparel  Apparel
# 587       Skechers U.S.A.    4181.0    179.2       8150  Apparel  Apparel
# 678               Carters    3400.0    302.8      20900  Apparel  Apparel
# 766   G-III Apparel Group    2807.0     62.1       9961  Apparel  Apparel
# 774          Fossil Group    2788.0   -478.2      12300  Apparel  Apparel
# ...

# %%
sectors.mean(numeric_only=True)
# Out:
#                                    Revenues      Profits      Employees
# Sector
# Aerospace & Defense            15353.400000  1069.340000   40404.960000
# Apparel                         7225.521429   453.621429   25407.071429
# Business Services               5963.962264   701.494340   30075.452830
# Chemicals                       7610.636364   620.454545   14364.242424
# Energy                         14425.300935   805.373585    9170.158879
# Engineering & Construction      6399.333333   263.740741   15583.148148
# Financials                     15757.935484  1704.861290   22581.412903
# Food &  Drug Stores            33789.000000   703.358333  116506.166667
# Food, Beverages & Tobacco      13790.054054  1483.851351   29170.702703
# Health Care                    21239.315493  1306.916901   41847.732394
# Hotels, Restaurants & Leisure   6916.346154   819.442308   88628.346154
# Household Products              8277.850000   990.242857   24103.428571
# ...

# %%
sectors.sum(numeric_only=True)
# Out:
#                                 Revenues   Profits  Employees
# Sector
# Aerospace & Defense             383835.0   26733.5    1010124
# Apparel                         101157.3    6350.7     355699
# Business Services               316090.0   37179.2    1593999
# Chemicals                       251151.0   20475.0     474020
# Energy                         1543507.2   85369.6     981207
# Engineering & Construction      172782.0    7121.0     420745
# Financials                     2442480.0  264253.5    3500119
# Food &  Drug Stores             405468.0    8440.3    1398074
# Food, Beverages & Tobacco       510232.0   54902.5    1079316
# Health Care                    1507991.4   92791.1    2971189
# Hotels, Restaurants & Leisure   179825.0   21305.5    2304337
# Household Products              231779.8   27726.8     674896
# Industrials                     520140.0   19114.3    1566110
# Materials                       278298.0   13730.4     653751
# ...

# %%
sectors.min(numeric_only=True)
# Out:
#                                Revenues  Profits  Employees
# Sector
# Aerospace & Defense              1877.0    -74.0       5157
# Apparel                          2350.0   -478.2       3700
# Business Services                1851.0   -557.1       2338
# Chemicals                        1925.0   -296.2       1931
# Energy                           1874.0  -5723.0        593
# Engineering & Construction       1906.0   -332.2       1100
# Financials                       1848.0  -6798.0        152
# Food &  Drug Stores              2064.0   -373.3       7324
# Food, Beverages & Tobacco        2071.0   -286.2       1819
# Health Care                      1849.0  -2459.0       2298
# Hotels, Restaurants & Leisure    1907.0   -375.0       8600
# Household Products               1949.0  -1053.8       4050
# Industrials                      1918.0  -5786.0       4125
# Materials                        1933.0   -258.0        126
# ...

# %%
sectors.max(numeric_only=True)
# Out:
#                                Revenues  Profits  Employees
# Sector
# Aerospace & Defense             93392.0   8197.0     204700
# Apparel                         34350.0   4240.0      74400
# Business Services               21034.0   6699.0     215000
# Chemicals                       62683.0   3000.4      98000
# Energy                         244363.0  19710.0      71200
# Engineering & Construction      19521.0   1038.4      87000
# Financials                     242137.0  44940.0     377000
# Food &  Drug Stores            122662.0   4078.0     449000
# Food, Beverages & Tobacco       63525.0  10999.0     263000
# Health Care                    201159.0  21308.0     260000
# Hotels, Restaurants & Leisure   22894.0   5192.3     450000
# Household Products              66217.0  15326.0      95000
# Industrials                    122274.0   4858.0     313000
# Materials                       23302.0   2144.0      56000
# ...

# %%
sectors['Profits'].max(numeric_only=True)
# Out:
# Sector
# Aerospace & Defense               8197.0
# Apparel                           4240.0
# Business Services                 6699.0
# Chemicals                         3000.4
# Energy                           19710.0
# Engineering & Construction        1038.4
# Financials                       44940.0
# Food &  Drug Stores               4078.0
# Food, Beverages & Tobacco        10999.0
# Health Care                      21308.0
# Hotels, Restaurants & Leisure     5192.3
# Household Products               15326.0
# Industrials                       4858.0
# Materials                         2144.0
# Media                             8980.0
# Motor Vehicles & Parts            7602.0
# Retailing                         9862.0
# Technology                       48351.0
# Telecommunications               30101.0
# Transportation                   10712.0
# Wholesalers                       5070.0
# Name: Profits, dtype: float64

# %%
sectors['Profits'].min(numeric_only=True)
# Out:
# Sector
# Aerospace & Defense               -74.0
# Apparel                          -478.2
# Business Services                -557.1
# Chemicals                        -296.2
# Energy                          -5723.0
# Engineering & Construction       -332.2
# Financials                      -6798.0
# Food &  Drug Stores              -373.3
# Food, Beverages & Tobacco        -286.2
# Health Care                     -2459.0
# Hotels, Restaurants & Leisure    -375.0
# Household Products              -1053.8
# Industrials                     -5786.0
# Materials                        -258.0
# Media                            -738.0
# Motor Vehicles & Parts          -3864.0
# Retailing                       -1067.3
# Technology                      -3728.0
# Telecommunications              -2116.6
# Transportation                   -106.7
# Wholesalers                      -267.0
# Name: Profits, dtype: float64

# %%
sectors.agg({"Revenues": "sum", "Profits": "mean", "Employees": "min"})
# Out:
#                                 Revenues      Profits  Employees
# Sector
# Aerospace & Defense             383835.0  1069.340000       5157
# Apparel                         101157.3   453.621429       3700
# Business Services               316090.0   701.494340       2338
# Chemicals                       251151.0   620.454545       1931
# Energy                         1543507.2   805.373585        593
# Engineering & Construction      172782.0   263.740741       1100
# Financials                     2442480.0  1704.861290        152
# Food &  Drug Stores             405468.0   703.358333       7324
# Food, Beverages & Tobacco       510232.0  1483.851351       1819
# Health Care                    1507991.4  1306.916901       2298
# Hotels, Restaurants & Leisure   179825.0   819.442308       8600
# Household Products              231779.8   990.242857       4050
# Industrials                     520140.0   390.087755       4125
# ...

# %%
def get_largest_profits(df):
    return df.nlargest(1, 'Profits')
sectors.apply(get_largest_profits,include_groups=False)
# Out:
#                                                     Company  Revenues  \
# Sector
# Aerospace & Defense           26                     Boeing   93392.0
# Apparel                       88                       Nike   34350.0
# Business Services             160                      Visa   18358.0
# Chemicals                     344  Air Products & Chemicals    8442.0
# Energy                        1                 Exxon Mobil  244363.0
# Engineering & Construction    210               D.R. Horton   14091.0
# Financials                    2          Berkshire Hathaway  242137.0
# Food &  Drug Stores           18   Walgreens Boots Alliance  118214.0
# Food, Beverages & Tobacco     113               Kraft Heinz   26232.0
# Health Care                   56                     Pfizer   52546.0
# Hotels, Restaurants & Leisure 130                 McDonalds   22820.0
# Household Products            41           Procter & Gamble   66217.0
# ...

# %%
sector = ft.groupby(['Sector','Industry'])
sector.size()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            25
# Apparel              Apparel                                          14
# Business Services    Advertising, marketing                            2
#                      Diversified Outsourcing Services                 14
#                      Education                                         2
#                                                                       ..
# Transportation       Trucking, Truck Leasing                          11
# Wholesalers          Wholesalers: Diversified                         24
#                      Wholesalers: Electronics and Office Equipment     8
#                      Wholesalers: Food and Grocery                     6
#                      Wholesalers: Health Care                          6
# Length: 82, dtype: int64

# %%
sector.get_group(('Business Services','Education'))
# Out:
#                 Company  Revenues  Profits  Employees             Sector  \
# 567  Laureate Education    4378.0     91.5      54500  Business Services
# 810     Graham Holdings    2592.0    302.0      16153  Business Services
#
#       Industry
# 567  Education
# 810  Education
